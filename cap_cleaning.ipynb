# %% [markdown]
# #Libraries

# %%
import pandas as pd

# %% [markdown]
# #Importing

# %%
data = pd.read_csv('cleaned_all_phones.csv')

# %% [markdown]
# #Cleanup

# %%
download_cap = False # Set to True if you want to download the cleaned data

# %% [markdown]
# ###Multiplying resolution to get pixels

# %%
cleaned = data.copy()

# %%
cleaned[['resolution_height', 'resolution_width']] = cleaned['resolution'].str.split('x', expand=True)

# %%
cleaned.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_8K  \
# 0        Li-Po        2        2016-09-01      140.0  ...     False
# 1       Li-Ion        2        2016-12-01      140.0  ...     False
# 2       Li-Ion        4        2017-01-01      147.0  ...     False
# 3        Li-Po        4        2017-01-01      165.0  ...     False
# 4       Li-Ion        4        2017-02-01      145.0  ...     False
#
#    video_30fps  video_60fps  video_120fps  video_240fps  video_480fps  \
# 0         True        False         False         False         False
# ...

# %%
cleaned['resolution'] = cleaned['resolution_height'].astype(int) * cleaned['resolution_width'].astype(int)
cleaned.drop(['resolution_height', 'resolution_width'], axis=1, inplace=True)

# %%
cleaned.head()
# Out:
#        phone_name   brand           os  inches  resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0      921600     2200
# 1        K20 plus      LG  Android 7.0     5.3      921600     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2     2073600     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5     2073600     4100
# 4             P10  Huawei  Android 7.0     5.1     2073600     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %% [markdown]
# #Checking for null values

# %%
cleaned.isnull().sum()
# Out:
# phone_name           0
# brand                0
# os                   0
# inches               0
# resolution           0
# battery              0
# battery_type         0
# ram(GB)              0
# announcement_date    0
# weight(g)            0
# storage(GB)          0
# video_720p           0
# video_1080p          0
# video_4K             0
# video_8K             0
# video_30fps          0
# video_60fps          0
# video_120fps         0
# video_240fps         0
# video_480fps         0
# video_960fps         0
# price(USD)           0
# dtype: int64

# %% [markdown]
# ##Saving and downloading

# %%
cleaned.to_csv('Cleaned cleaned_all_phones.csv', index=False)
if download_cap:
  from google.colab import files
  files.download('Cleaned cleaned_all_phones.csv')
