# %% [markdown]
# #Libraries

# %%
import pandas as pd

# %% [markdown]
# #Importing

# %%
data = pd.read_csv('smartphones.csv')

# %% [markdown]
# #Cleanup

# %%
download_smartphones = False  #Set to true to download cleaned csv

# %% [markdown]
# ###Multiplying resolution to get pixels

# %%
cleaned = data.copy()

# %%
cleaned.head()
# Out:
#   brand_name                    model   price  avg_rating  5G_or_not  \
# 0      apple          Apple iPhone 11   38999         7.3          0
# 1      apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2      apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 3      apple          Apple iPhone 12   51999         7.4          1
# 4      apple  Apple iPhone 12 (128GB)   55999         7.5          1
#
#   processor_brand  num_cores  processor_speed  battery_capacity  \
# 0          bionic        6.0             2.65            3110.0
# 1          bionic        6.0             2.65            3110.0
# 2          bionic        6.0             2.65            3500.0
# 3          bionic        6.0             3.10               NaN
# 4          bionic        6.0             3.10               NaN
#
#    fast_charging_available  ...  internal_memory  screen_size  refresh_rate  \
# 0                        0  ...               64          6.1            60
# ...

# %%
cleaned['resolution'] = cleaned['resolution_height'].astype(int) * cleaned['resolution_width'].astype(int)
cleaned.drop(['resolution_height', 'resolution_width'], axis=1, inplace=True)

# %%
cleaned.head()
# Out:
#   brand_name                    model   price  avg_rating  5G_or_not  \
# 0      apple          Apple iPhone 11   38999         7.3          0
# 1      apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2      apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 3      apple          Apple iPhone 12   51999         7.4          1
# 4      apple  Apple iPhone 12 (128GB)   55999         7.5          1
#
#   processor_brand  num_cores  processor_speed  battery_capacity  \
# 0          bionic        6.0             2.65            3110.0
# 1          bionic        6.0             2.65            3110.0
# 2          bionic        6.0             2.65            3500.0
# 3          bionic        6.0             3.10               NaN
# 4          bionic        6.0             3.10               NaN
#
#    fast_charging_available  ...  ram_capacity  internal_memory  screen_size  \
# 0                        0  ...             4               64          6.1
# ...

# %% [markdown]
# #Checking for null values

# %%
cleaned.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# avg_rating                   101
# 5G_or_not                      0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# resolution                     0
# dtype: int64

# %% [markdown]
# #Dropping 'fast_charging'

# %% [markdown]
# According the the Kaggle page, this column does not exist.
#
# https://www.kaggle.com/datasets/abhijitdahatonde/real-world-smartphones-dataset?resource=download

# %%
cleaned.drop('fast_charging', axis=1, inplace=True)

# %%
cleaned.head()
# Out:
#   brand_name                    model   price  avg_rating  5G_or_not  \
# 0      apple          Apple iPhone 11   38999         7.3          0
# 1      apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2      apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 3      apple          Apple iPhone 12   51999         7.4          1
# 4      apple  Apple iPhone 12 (128GB)   55999         7.5          1
#
#   processor_brand  num_cores  processor_speed  battery_capacity  \
# 0          bionic        6.0             2.65            3110.0
# 1          bionic        6.0             2.65            3110.0
# 2          bionic        6.0             2.65            3500.0
# 3          bionic        6.0             3.10               NaN
# 4          bionic        6.0             3.10               NaN
#
#    fast_charging_available  ram_capacity  internal_memory  screen_size  \
# 0                        0             4               64          6.1
# ...

# %%
cleaned.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# avg_rating                   101
# 5G_or_not                      0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# resolution                     0
# dtype: int64

# %% [markdown]
# #Dropping null values

# %%
cleaned.dropna(inplace=True)

# %% [markdown]
# #Looking at result of cleaning

# %%
cleaned.isnull().sum()

# %%
print(cleaned.shape)
cleaned.head()
# Out:
# (814, 20)
#    brand_name                    model   price  avg_rating  5G_or_not  \
# 0       apple          Apple iPhone 11   38999         7.3          0
# 1       apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2       apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 11      apple          Apple iPhone 13   62999         7.9          1
# 12      apple  Apple iPhone 13 (256GB)   72999         7.9          1
#
#    processor_brand  num_cores  processor_speed  battery_capacity  \
# 0           bionic        6.0             2.65            3110.0
# 1           bionic        6.0             2.65            3110.0
# 2           bionic        6.0             2.65            3500.0
# 11          bionic        6.0             3.22            3240.0
# 12          bionic        6.0             3.22            3240.0
#
#     fast_charging_available  ram_capacity  internal_memory  screen_size  \
# ...

# %% [markdown]
# ##Saving and downloading

# %%
cleaned.to_csv('Cleaned smartphones.csv', index=False)
if download_smartphones:
  from google.colab import files
  files.download('Cleaned smartphones.csv')
