# %% [markdown]
# # Smartphones dataset (Using Sklearn and Keras)

# %% [markdown]
# ##Importing Necessary Libraries

# %%
import math

# Data handling and stuff
import pandas as pd
import numpy as np

# Neural Network Magic Libraries (TensorFlow/Keras)
from tensorflow import keras
print('Tensorflow/Keras: %s' % keras.__version__)
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.losses import Huber
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras.layers import Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.layers import BatchNormalization
from keras import Input

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import classification_report
from sklearn.preprocessing import TargetEncoder

# Visualization - remove if not used
import matplotlib.pyplot as plt
# import seaborn as sns
# Out:
# Tensorflow/Keras: 3.8.0

# %% [markdown]
# ##Visualization Formatting

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.float_format", lambda x: "%.2f" % x)

# %% [markdown]
# ## Data Acquisition and Preprocessing
# ##### Importing and Cleaning initial Dataset for Processing

# %%
def read_csv(file_path):
    df = pd.read_csv(file_path)
    return df

def clean_data(df):
    df = df.drop_duplicates()
    df = df.dropna()
    df = df.reset_index(drop=True)
    return df

# %%
# np.random.seed(42)

# %%
smartphones = read_csv("Cleaned smartphones.csv")
cleaned_smartphones = clean_data(smartphones)
cleaned_smartphones.head()
cleaned_smartphones.info()

y = cleaned_smartphones["price"]
X = cleaned_smartphones.drop("price", axis=1)


categorical_cols = X.select_dtypes(include=['object']).columns
for col in categorical_cols:
    te = TargetEncoder(target_type="continuous", random_state=42, smooth = 'auto')
    data_array = X[col].values.reshape(-1, 1)
    X[col] = te.fit_transform(X[[col]], y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 870 non-null    object
#  1   price                      870 non-null    float64
#  2   avg_rating                 870 non-null    float64
#  3   5G_or_not                  870 non-null    int64
#  4   processor_brand            870 non-null    object
#  5   num_cores                  870 non-null    float64
#  6   processor_speed            870 non-null    float64
#  7   battery_capacity           870 non-null    float64
#  8   fast_charging_available    870 non-null    int64
#  9   ram_capacity               870 non-null    int64
#  10  internal_memory            870 non-null    int64
#  11  screen_size                870 non-null    float64
#  12  refresh_rate               870 non-null    int64
#  13  num_rear_cameras           870 non-null    int64
#  14  os                         870 non-null    object
#  15  primary_camera_rear        870 non-null    float64
#  16  primary_camera_front       870 non-null    float64
#  17  extended_memory_available  870 non-null    int64
#  18  resolution_height          870 non-null    int64
#  19  resolution_width           870 non-null    int64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 136.1+ KB

# %% [markdown]
# ##Building our Feedforward Neural Network

# %% [markdown]
# ##### Splitting training and testing samples

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Scaling our Data for Processing

# %%
# Scale Features
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
# Scale Target
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

# %% [markdown]
# ##### Defining the Structure of the Neural Network

# %%
model = Sequential(name="Smartphones_NN")
model.add(Input(shape=(X_train_scaled.shape[1],)))# Input Layer
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3)) # Deactivates % of neurons if they are not improving performance
model.add(Dense(64, activation='relu')) # Hidden Layer 2
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(32, activation='relu')) # Hidden Layer 3
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(1)) # Output Layer

# %% [markdown]
# ##### Compile Keras model aka Magic

# %%
model.compile(
    optimizer=Adam(learning_rate=0.005),
    loss=Huber(delta=1.0),  # Handles Outliers better than mse
    metrics=['mae']
)

# %%
print("X_train_scaled shape:", X_train_scaled.shape)
print("y_train_scaled shape:", y_train_scaled.shape)
# Out:
# X_train_scaled shape: (696, 19)
# y_train_scaled shape: (696, 1)

# %% [markdown]
# ##### Fitting keras model onto the dataset

# %%
batch_size = 64
early_stop = EarlyStopping(monitor='val_mae', patience=25, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(
    monitor='val_mae',
    factor=0.2,         # Reduce LR by 50%
    patience=10,         # Wait 5 epochs w/o improvement before reducing LR
    min_lr=1e-4,        # Smallest allowed LR
    verbose=1           # Print a message when LR changes
)
history = model.fit(X_train_scaled, y_train_scaled,
                    validation_data=(X_test_scaled, y_test_scaled),
                    epochs=200,
                    batch_size=batch_size,
                    verbose=1,
                    callbacks=[reduce_lr, early_stop])


# model.fit(X_train_scaled, y_train_scaled, batch_size=batch_size,steps_per_epoch=steps_per_epoch, epochs=10)
# Out:
# Epoch 1/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.6230 - mae: 1.0089 - val_loss: 0.3176 - val_mae: 0.6605 - learning_rate: 0.0050
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3584 - mae: 0.7034 - val_loss: 0.2020 - val_mae: 0.5124 - learning_rate: 0.0050
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2780 - mae: 0.5951 - val_loss: 0.1748 - val_mae: 0.4970 - learning_rate: 0.0050
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2243 - mae: 0.5280 - val_loss: 0.1368 - val_mae: 0.4239 - learning_rate: 0.0050
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1740 - mae: 0.4460 - val_loss: 0.1533 - val_mae: 0.4391 - learning_rate: 0.0050
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1561 - mae: 0.4201 - val_loss: 0.1283 - val_mae: 0.3922 - learning_rate: 0.0050
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1429 - mae: 0.3985 - val_loss: 0.1347 - val_mae: 0.3997 - learning_rate: 0.0050
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1535 - mae: 0.4161 - val_loss: 0.1230 - val_mae: 0.3841 - learning_rate: 0.0050
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1432 - mae: 0.3881 - val_loss: 0.1157 - val_mae: 0.3579 - learning_rate: 0.0050
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1246 - mae: 0.3683 - val_loss: 0.1186 - val_mae: 0.3583 - learning_rate: 0.0050
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1338 - mae: 0.3709 - val_loss: 0.1253 - val_mae: 0.3629 - learning_rate: 0.0050
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1150 - mae: 0.3463 - val_loss: 0.1264 - val_mae: 0.3689 - learning_rate: 0.0050
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1251 - mae: 0.3656 - val_loss: 0.1122 - val_mae: 0.3487 - learning_rate: 0.0050
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1044 - mae: 0.3229 - val_loss: 0.1099 - val_mae: 0.3514 - learning_rate: 0.0050
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1169 - mae: 0.3517 - val_loss: 0.1117 - val_mae: 0.3327 - learning_rate: 0.0050
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1217 - mae: 0.3455 - val_loss: 0.1165 - val_mae: 0.3457 - learning_rate: 0.0050
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1038 - mae: 0.3244 - val_loss: 0.1160 - val_mae: 0.3459 - learning_rate: 0.0050
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1156 - mae: 0.3458 - val_loss: 0.1175 - val_mae: 0.3388 - learning_rate: 0.0050
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1218 - mae: 0.3525 - val_loss: 0.1057 - val_mae: 0.3177 - learning_rate: 0.0050
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0959 - mae: 0.3117 - val_loss: 0.1081 - val_mae: 0.3322 - learning_rate: 0.0050
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1101 - mae: 0.3310 - val_loss: 0.1013 - val_mae: 0.3022 - learning_rate: 0.0050
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0991 - mae: 0.3149 - val_loss: 0.1034 - val_mae: 0.3095 - learning_rate: 0.0050
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1091 - mae: 0.3252 - val_loss: 0.1068 - val_mae: 0.3119 - learning_rate: 0.0050
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0962 - mae: 0.3026 - val_loss: 0.1031 - val_mae: 0.3025 - learning_rate: 0.0050
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0985 - mae: 0.3104 - val_loss: 0.1063 - val_mae: 0.3043 - learning_rate: 0.0050
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1069 - mae: 0.3183 - val_loss: 0.1165 - val_mae: 0.3279 - learning_rate: 0.0050
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1146 - mae: 0.3441 - val_loss: 0.1044 - val_mae: 0.3021 - learning_rate: 0.0050
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0947 - mae: 0.3097 - val_loss: 0.1008 - val_mae: 0.3016 - learning_rate: 0.0050
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1053 - mae: 0.3262 - val_loss: 0.0982 - val_mae: 0.2929 - learning_rate: 0.0050
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0889 - mae: 0.3059 - val_loss: 0.1015 - val_mae: 0.3058 - learning_rate: 0.0050
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0911 - mae: 0.3001 - val_loss: 0.1050 - val_mae: 0.3095 - learning_rate: 0.0050
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0868 - mae: 0.2963 - val_loss: 0.0937 - val_mae: 0.2920 - learning_rate: 0.0050
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0945 - mae: 0.3048 - val_loss: 0.1054 - val_mae: 0.3270 - learning_rate: 0.0050
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0943 - mae: 0.3057 - val_loss: 0.0976 - val_mae: 0.2936 - learning_rate: 0.0050
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0807 - mae: 0.2776 - val_loss: 0.0970 - val_mae: 0.2922 - learning_rate: 0.0050
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0851 - mae: 0.2907 - val_loss: 0.0980 - val_mae: 0.2972 - learning_rate: 0.0050
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0948 - mae: 0.3023 - val_loss: 0.0945 - val_mae: 0.2858 - learning_rate: 0.0050
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0860 - mae: 0.2984 - val_loss: 0.0980 - val_mae: 0.2986 - learning_rate: 0.0050
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0759 - mae: 0.2720 - val_loss: 0.0954 - val_mae: 0.2871 - learning_rate: 0.0050
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0871 - mae: 0.3009 - val_loss: 0.1022 - val_mae: 0.3035 - learning_rate: 0.0050
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0851 - mae: 0.3051 - val_loss: 0.0959 - val_mae: 0.2925 - learning_rate: 0.0050
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0915 - mae: 0.3061 - val_loss: 0.0985 - val_mae: 0.2942 - learning_rate: 0.0050
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0940 - mae: 0.3034 - val_loss: 0.0909 - val_mae: 0.2890 - learning_rate: 0.0050
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0836 - mae: 0.2922 - val_loss: 0.0902 - val_mae: 0.2874 - learning_rate: 0.0050
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0708 - mae: 0.2746 - val_loss: 0.0967 - val_mae: 0.2915 - learning_rate: 0.0050
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0862 - mae: 0.2840 - val_loss: 0.0952 - val_mae: 0.2896 - learning_rate: 0.0050
# Epoch 47/200
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.1022 - mae: 0.3316
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0968 - mae: 0.3109 - val_loss: 0.0914 - val_mae: 0.2926 - learning_rate: 0.0050
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0915 - mae: 0.3037 - val_loss: 0.0928 - val_mae: 0.2950 - learning_rate: 1.0000e-03
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0962 - mae: 0.3162 - val_loss: 0.0909 - val_mae: 0.2853 - learning_rate: 1.0000e-03
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0792 - mae: 0.2688 - val_loss: 0.0902 - val_mae: 0.2837 - learning_rate: 1.0000e-03
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0794 - mae: 0.2875 - val_loss: 0.0904 - val_mae: 0.2887 - learning_rate: 1.0000e-03
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0839 - mae: 0.2918 - val_loss: 0.0892 - val_mae: 0.2826 - learning_rate: 1.0000e-03
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0660 - mae: 0.2648 - val_loss: 0.0896 - val_mae: 0.2837 - learning_rate: 1.0000e-03
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1002 - mae: 0.3137 - val_loss: 0.0876 - val_mae: 0.2782 - learning_rate: 1.0000e-03
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0807 - mae: 0.2908 - val_loss: 0.0897 - val_mae: 0.2818 - learning_rate: 1.0000e-03
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0734 - mae: 0.2684 - val_loss: 0.0922 - val_mae: 0.2868 - learning_rate: 1.0000e-03
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0759 - mae: 0.2680 - val_loss: 0.0917 - val_mae: 0.2859 - learning_rate: 1.0000e-03
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0758 - mae: 0.2772 - val_loss: 0.0903 - val_mae: 0.2794 - learning_rate: 1.0000e-03
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0713 - mae: 0.2727 - val_loss: 0.0919 - val_mae: 0.2842 - learning_rate: 1.0000e-03
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0781 - mae: 0.2830 - val_loss: 0.0919 - val_mae: 0.2821 - learning_rate: 1.0000e-03
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0728 - mae: 0.2743 - val_loss: 0.0920 - val_mae: 0.2783 - learning_rate: 1.0000e-03
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0985 - mae: 0.3200 - val_loss: 0.0906 - val_mae: 0.2773 - learning_rate: 1.0000e-03
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0785 - mae: 0.2842 - val_loss: 0.0915 - val_mae: 0.2842 - learning_rate: 1.0000e-03
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0712 - mae: 0.2676 - val_loss: 0.0901 - val_mae: 0.2788 - learning_rate: 1.0000e-03
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0785 - mae: 0.2876 - val_loss: 0.0889 - val_mae: 0.2764 - learning_rate: 1.0000e-03
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0797 - mae: 0.2855 - val_loss: 0.0886 - val_mae: 0.2772 - learning_rate: 1.0000e-03
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0746 - mae: 0.2783 - val_loss: 0.0872 - val_mae: 0.2793 - learning_rate: 1.0000e-03
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0848 - mae: 0.2919 - val_loss: 0.0875 - val_mae: 0.2795 - learning_rate: 1.0000e-03
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0675 - mae: 0.2689 - val_loss: 0.0850 - val_mae: 0.2709 - learning_rate: 1.0000e-03
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0632 - mae: 0.2592 - val_loss: 0.0882 - val_mae: 0.2768 - learning_rate: 1.0000e-03
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0695 - mae: 0.2702 - val_loss: 0.0889 - val_mae: 0.2778 - learning_rate: 1.0000e-03
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0927 - mae: 0.2952 - val_loss: 0.0852 - val_mae: 0.2729 - learning_rate: 1.0000e-03
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0859 - mae: 0.2933 - val_loss: 0.0840 - val_mae: 0.2741 - learning_rate: 1.0000e-03
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0685 - mae: 0.2509 - val_loss: 0.0870 - val_mae: 0.2771 - learning_rate: 1.0000e-03
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0808 - mae: 0.2872 - val_loss: 0.0929 - val_mae: 0.2839 - learning_rate: 1.0000e-03
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0752 - mae: 0.2867 - val_loss: 0.0882 - val_mae: 0.2712 - learning_rate: 1.0000e-03
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0623 - mae: 0.2485 - val_loss: 0.0837 - val_mae: 0.2661 - learning_rate: 1.0000e-03
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0758 - mae: 0.2825 - val_loss: 0.0850 - val_mae: 0.2706 - learning_rate: 1.0000e-03
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0733 - mae: 0.2663 - val_loss: 0.0856 - val_mae: 0.2723 - learning_rate: 1.0000e-03
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0679 - mae: 0.2695 - val_loss: 0.0848 - val_mae: 0.2697 - learning_rate: 1.0000e-03
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0648 - mae: 0.2548 - val_loss: 0.0843 - val_mae: 0.2684 - learning_rate: 1.0000e-03
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0948 - mae: 0.3046 - val_loss: 0.0866 - val_mae: 0.2751 - learning_rate: 1.0000e-03
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0740 - mae: 0.2834 - val_loss: 0.0858 - val_mae: 0.2738 - learning_rate: 1.0000e-03
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0695 - mae: 0.2636 - val_loss: 0.0825 - val_mae: 0.2628 - learning_rate: 1.0000e-03
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0721 - mae: 0.2669 - val_loss: 0.0824 - val_mae: 0.2636 - learning_rate: 1.0000e-03
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0872 - mae: 0.2980 - val_loss: 0.0845 - val_mae: 0.2682 - learning_rate: 1.0000e-03
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0719 - mae: 0.2684 - val_loss: 0.0880 - val_mae: 0.2778 - learning_rate: 1.0000e-03
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0690 - mae: 0.2688 - val_loss: 0.0923 - val_mae: 0.2862 - learning_rate: 1.0000e-03
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0663 - mae: 0.2577 - val_loss: 0.0847 - val_mae: 0.2692 - learning_rate: 1.0000e-03
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0757 - mae: 0.2867 - val_loss: 0.0874 - val_mae: 0.2709 - learning_rate: 1.0000e-03
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0837 - mae: 0.2895 - val_loss: 0.0857 - val_mae: 0.2745 - learning_rate: 1.0000e-03
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0679 - mae: 0.2840 - val_loss: 0.0846 - val_mae: 0.2738 - learning_rate: 1.0000e-03
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0681 - mae: 0.2610 - val_loss: 0.0857 - val_mae: 0.2702 - learning_rate: 1.0000e-03
# Epoch 94/200
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0786 - mae: 0.3015
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0001999999862164259.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0796 - mae: 0.2948 - val_loss: 0.0858 - val_mae: 0.2713 - learning_rate: 1.0000e-03
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0850 - mae: 0.2922 - val_loss: 0.0856 - val_mae: 0.2706 - learning_rate: 2.0000e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0830 - mae: 0.2966 - val_loss: 0.0846 - val_mae: 0.2689 - learning_rate: 2.0000e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0689 - mae: 0.2595 - val_loss: 0.0837 - val_mae: 0.2674 - learning_rate: 2.0000e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0613 - mae: 0.2562 - val_loss: 0.0837 - val_mae: 0.2685 - learning_rate: 2.0000e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0667 - mae: 0.2576 - val_loss: 0.0834 - val_mae: 0.2694 - learning_rate: 2.0000e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0569 - mae: 0.2428 - val_loss: 0.0835 - val_mae: 0.2701 - learning_rate: 2.0000e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0697 - mae: 0.2680 - val_loss: 0.0831 - val_mae: 0.2707 - learning_rate: 2.0000e-04
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0608 - mae: 0.2505 - val_loss: 0.0832 - val_mae: 0.2709 - learning_rate: 2.0000e-04
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0644 - mae: 0.2578 - val_loss: 0.0836 - val_mae: 0.2710 - learning_rate: 2.0000e-04
# Epoch 104/200
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 0.0509 - mae: 0.2382
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.0001.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0665 - mae: 0.2625 - val_loss: 0.0842 - val_mae: 0.2709 - learning_rate: 2.0000e-04
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0816 - mae: 0.2804 - val_loss: 0.0839 - val_mae: 0.2704 - learning_rate: 1.0000e-04
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0637 - mae: 0.2647 - val_loss: 0.0837 - val_mae: 0.2704 - learning_rate: 1.0000e-04
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0599 - mae: 0.2490 - val_loss: 0.0838 - val_mae: 0.2708 - learning_rate: 1.0000e-04
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0697 - mae: 0.2682 - val_loss: 0.0836 - val_mae: 0.2707 - learning_rate: 1.0000e-04
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0539 - mae: 0.2410 - val_loss: 0.0835 - val_mae: 0.2704 - learning_rate: 1.0000e-04

# %% [markdown]
# ##### Making Predictions with our model

# %% [markdown]
# Evaluating model

# %%
# Get your scaled test predictions
y_pred_scaled = model.predict(X_test_scaled)

# Inverse transform BOTH predictions and true values
y_pred_dollars = scaler_y.inverse_transform(y_pred_scaled).flatten()
y_true_dollars = scaler_y.inverse_transform(y_test_scaled).flatten()

# Calculate MAE in original dollars
test_loss, test_mae = model.evaluate(X_test_scaled, y_test_scaled, verbose=0)
print(f"Test MAE: {test_mae:.4f}")
mae_dollars = mean_absolute_error(y_true_dollars, y_pred_dollars)

print(f"Official Test MAE (USD): ±${mae_dollars:.2f}")
print(f'Mean Absolute Percentage Error: {mean_absolute_percentage_error(y_true_dollars, y_pred_dollars):.2f}')
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Test MAE: 0.2628
# Official Test MAE (USD): ±$42.81
# Mean Absolute Percentage Error: 0.18

# %% [markdown]
# Bias Check

# %%
predictions = model.predict(X_test_scaled)
errors = y_test - predictions.flatten()
plt.hist(errors, bins=30)
plt.title("Error Distribution")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Text(0.5, 1.0, 'Error Distribution')

# %%
# Make predictions and compare with true values
y_pred_scaled = model.predict(X_test_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# ##Plots

# %%
# Plot Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.show()

# %%
# Plot MAE
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('MAE Over Epochs')
plt.legend()
plt.show()

# %%
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.xlabel("True Prices")
plt.ylabel("Predicted Prices")
plt.title("Real World Smartphone's Dataset\n Feedforward Neural Network Model Predictions vs True Values")
plt.show()
